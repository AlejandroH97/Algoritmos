# %%
import pylab as pl
from itertools import permutations

# %%
def insertion_sort(lista):

    ins = 0
    comp = 0
    swaps = 0
    k = 1
    i = 1
    while (i < len(lista)):
        key = lista[k]
        ins += 3
        comp += 1
        while (k > 0) and (key < lista[k-1]):
            comp+= 1
            lista[k], lista[k-1] = lista[k-1], lista[k]
            swaps += 1
            k=k-1
            ins += 3
        i = i+1
        k = i
        ins += 1
    return ins, comp, swaps

# %%
max = 9
for n in range(max+1):

    instruccionespromedio = []
    comparasionespromedio = []
    swapspromedio = []


    for n in range(n, (n+1)):

        permut = list(permutations(range(n)))
        print("Para %s hay %s permutacioies" % (n, len(permut)))
        for p in permut:
            p = list(p)
            psorted = insertion_sort(p)
            instruccionespromedio.append(psorted[0])
            comparasionespromedio.append(psorted[1])
            swapspromedio.append(psorted[2])

    pl.hist(instruccionespromedio, bins='auto')
    pl.title("Histograma de pasos con todas las permutaciones de tamano N = %s" % (n))
    pl.show()

    pl.hist(comparasionespromedio, bins='auto')
    pl.title("Histograma de comparaciones con todas las permutaciones de tamano N = %s" % (n))
    pl.show()

    pl.hist(swapspromedio, bins='auto')
    pl.title("Histograma de swaps con todas las permutaciones de tamano N = %s" % (n))
    pl.show()
# Out:
# Para 0 hay 1 permutacioies
# Para 1 hay 1 permutacioies
# Para 2 hay 2 permutacioies
# Para 3 hay 6 permutacioies
# Para 4 hay 24 permutacioies
# Para 5 hay 120 permutacioies
# Para 6 hay 720 permutacioies
# Para 7 hay 5040 permutacioies
# Para 8 hay 40320 permutacioies
# Para 9 hay 362880 permutacioies

# %%
print "Insertion Sort con Iter Tools de N = 0 hasta N = 9"
# Out:
# Insertion Sort con Iter Tools de N = 0 hasta N = 9
