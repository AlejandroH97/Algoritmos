# %%
import numpy as np
import pylab as pl
import time
import matplotlib.pyplot as plt

# %%
longitud = int(raw_input("Ingrese el numero n de los arreglos de 1s y 2s de tamano nxn"))
listatiempos = []

for tamano in range(2, longitud+1, 1):
    A = np.full((tamano,tamano),1)
    B = np.full((tamano,tamano),2)
    listapromedio = []

    for tiempo in range(10):
        tiempoinicio = time.clock()
        np.dot(A,B)
        tiempofinal = time.clock()
        #tiempooperacion = (tiempofinal - tiempoinicio) en caso que se quiera el tiempo total
        tiempooperacion = (tiempofinal - tiempoinicio) / (2 * (tamano ** 3))
        listapromedio.append(tiempooperacion)

    promedio = np.average(listapromedio)
    listatiempos.append(promedio)

longitudn = np.arange(2, longitud+1, 1)
pl.ylabel("Tiempo total por paso")
pl.xlabel("Matrices cuadraticas de longitud N")
pl.plot(longitudn, listatiempos)
pl.show()

print listatiempos
# Out:
# Ingrese el numero n de los arreglos de 1s y 2s de tamano nxn100
# [3.1539495145697494e-07, 3.405394328349004e-08, 1.5368821787098348e-08, 1.06058234523837e-08, 8.612479842045452e-09, 5.85998427374722e-09, 4.719230603103591e-09, 3.695776790456283e-09, 3.207406286003135e-09, 2.602553560393213e-09, 2.017003181398575e-09, 2.0535964993071226e-09, 1.792282424151409e-09, 1.5395550172815033e-09, 1.4564882060463483e-09, 1.397079066160542e-09, 1.3932491868783525e-09, 1.2345170717376215e-09, 1.093190975812736e-09, 9.81281842530564e-10, 9.458354374577225e-10, 8.049051143746363e-10, 5.939641270376169e-10, 5.610822729648162e-10, 6.374908564199846e-10, 5.377453001986665e-10, 5.41580993384888e-10, 5.304251378440807e-10, 7.183006176308259e-10, 5.053011592642538e-10, 4.802756808468247e-10, 4.319739105728141e-10, 4.624288186279019e-10, 4.5483452405595486e-10, 4.4959784616042024e-10, 4.487358935003949e-10, 4.874939573054761e-10, 5.709841767425804e-10, 4.216402846808282e-10, 4.2131887585227795e-10, 4.187764569152501e-10, 4.052943994873997e-10, 4.171917455028499e-10, 3.977359784014872e-10, 4.2266305678406447e-10, 4.0593431704035565e-10, 3.917224353444691e-10, 4.620085610032084e-10, 4.928286671986678e-10, 3.899312635332119e-10, 3.812475136080374e-10, 3.7874354338101145e-10, 3.787302126904229e-10, 3.7438214920619387e-10, 3.851215562222091e-10, 3.689003034232812e-10, 3.779827066992215e-10, 3.826167914298786e-10, 3.9439218035298305e-10, 4.1412447248212864e-10, 3.8534596573862977e-10, 3.6694382451404313e-10, 3.7260518174393527e-10, 3.6283449049369403e-10, 3.663001910418567e-10, 3.704754054712499e-10, 4.012250043977404e-10, 3.619664678179961e-10, 3.6363072626348565e-10, 3.865377830510982e-10, 4.08865931198638e-10, 3.5645451252310883e-10, 3.642021562723117e-10, 3.905274537663893e-10, 3.9021923381037095e-10, 3.9432203910575497e-10, 3.650657986086155e-10, 3.733221010902498e-10, 3.619608109477738e-10, 3.5962345627950937e-10, 4.445875913816749e-10, 3.655486681308585e-10, 4.868528847408087e-10, 9.457659482646393e-10, 9.634146400555721e-10, 9.470045130140726e-10, 9.591080087835174e-10, 1.067210900271457e-09, 1.3163418317626767e-09, 1.3023070058198413e-09, 1.3252980190728445e-09, 1.3319715164633488e-09, 1.349922111131933e-09, 1.325297721053268e-09, 1.340527924408716e-09, 1.3890151710288828e-09, 1.4487748787949738e-09, 1.588421972256802e-09, 1.7501533140204692e-09]
