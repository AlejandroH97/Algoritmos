# %%
import numpy as np
import pylab as pl
import time
import matplotlib.pyplot as plt

# %%
longitud = int(raw_input("Ingrese el numero n de los arreglos de 1s y 2s de tamano nxn"))

def R(filas, columnas):
    matrizR = []
    for i in range(filas):
        matrizR.append([0]*columnas)
    for j in range(filas):
        for k in range(columnas):
            matrizR[j][k] = 0
    return matrizR

def A(filas, columnas):
    matrizA = []
    for i in range(filas):
        matrizA.append([0]*columnas)
    for j in range(filas):
        for k in range(columnas):
            matrizA[j][k] = 1
    return matrizA

def B(filas, columnas):
    matrizB = []
    for i in range(filas):
        matrizB.append([0] * columnas)
    for j in range(filas):
        for k in range(columnas):
            matrizB[j][k] = 2
    return matrizB

listatiempos = []

for tamano in range(2, longitud, 1):
    matrizA = A(tamano,tamano)
    matrizB = B(tamano,tamano)
    resultado = R(tamano,tamano)
    listapromedio = []

    for tiempo in range(10):
        tiempoinicio = time.clock()
        for i in range(tamano):
            for j in range(tamano):
                for k in range(tamano):
                    resultado[j][k] = resultado[j][k] + (matrizA[i][j] * matrizB[j][k])
        tiempofinal = time.clock()
        #tiempooperacion = (tiempofinal - tiempoinicio) en caso que se quiera el tiempo total
        tiempooperacion = (tiempofinal - tiempoinicio) / (2 * ((tamano) ** 3))
        listapromedio.append(tiempooperacion)

    promedio = np.average(listapromedio)
    listatiempos.append(promedio)

longitudn = np.arange(2, int(longitud), 1)
pl.ylabel("Tiempo total por paso")
pl.xlabel("Matrices cuadraticas de longitud N")
pl.plot(longitudn, listatiempos)
pl.show()

print listatiempos
# Out:
# Ingrese el numero n de los arreglos de 1s y 2s de tamano nxn150
# [6.120800350117861e-07, 4.4666102422962906e-07, 2.7797521120476174e-07, 2.943971318018157e-07, 2.8995348812983414e-07, 2.087775249733846e-07, 2.259383855562902e-07, 2.2975412380986763e-07, 1.990302513831921e-07, 1.9882223988413249e-07, 1.977405573077923e-07, 1.8848317443569636e-07, 1.9257685020627293e-07, 1.9010653433926764e-07, 1.857152972351006e-07, 1.868473563556296e-07, 1.8624075183984026e-07, 1.9557743185011896e-07, 1.8279275708152907e-07, 2.0041931241529426e-07, 1.8597012354867384e-07, 1.9069221472040298e-07, 1.863005607231853e-07, 1.8431415817613016e-07, 1.9437144875705107e-07, 1.8384262506510658e-07, 1.9912744765746288e-07, 1.9141859631785668e-07, 1.9641760119342237e-07, 1.98311325562692e-07, 1.9105705909225334e-07, 1.838215590990106e-07, 2.1125054116310908e-07, 2.1087365366043164e-07, 2.2483237939269703e-07, 2.3420594298536987e-07, 3.0169368243967803e-07, 2.3523899236116215e-07, 2.541872822707347e-07, 2.370477125842851e-07, 3.724123329177341e-07, 3.9115293292220966e-07, 4.